# %% [markdown]
# <a href="https://colab.research.google.com/github/OliveiraNaty/Repositor-Teste/blob/main/Avalia%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #AVALIAÇÃO - QUESTIONÁRIO COLAB/PYTON PROFESSOR NORI P.C.
# #ATIVIDADE I

# %%
nome = input("Digite seu nome: ")
print(f"Olá , {nome}! Qual é sua dúvida, caro estudante?")
resposta = input("Escolha um assunto: Inglês, Matemática, História, Português?").strip().lower()
if resposta == "inglês":
 print("Tranquilo, vamos falar sobre Inglês! Essa língua é muito importante!")
elif resposta == "matemática":
  print("Vamos resolver algumas questões então!")
elif resposta == "história":
  print("Quer saber algo histórico!")
elif resposta == "português":
  print("Tranquilo, vamos falar sobre Português! Você sabia que é considerado uma língua muito rica e complexa?")
else:
  print("Vou ficar devendo, estudante! Não entendi sua pergunta!")
# Out:
# Digite seu nome: Naty
# Olá , Naty! Qual é sua dúvida, caro estudante?
# Escolha um assunto: Inglês, Matemática, História, Português?Inglês
# Tranquilo, vamos falar sobre Inglês! Essa língua é muito importante!

# %% [markdown]
# #ATIVIDADE AVALIATIVA
# #ATIVIDADE II

# %%
nome = input("Digite seu nome: ")
print(f"Oii, {nome}! Qual é sua dúvida, caro estudante?")
resposta = input("Escolha um assunto entre: Esporte, Culinária, Futebol, Profissão, Atualidade?").strip().lower()
if resposta == "esporte":
 print("Legal, vamos falar um pouco desse assunto tão extraordinário!")
elif resposta == "culinária":
 print("Vamos falar sobre nossa amada Culinária!")
elif resposta == "futebol":
 print("Opa, futebol é a área do brasileiro não é?")
elif resposta == "profissão":
 print("Qual é sua curiosidade perante a diversidade de profissões?")
elif resposta == "atualidade":
 print("Vamos ver como anda essa atualidade!")
else:
  print("Foi mal, não entendi sua pergunta!")
# Out:
# Digite seu nome: Naty
# Oii, Naty! Qual é sua dúvida, caro estudante?
# Escolha um assunto entre: Esporte, Culinária, Futebol, Profissão, Atualidade?Atualidade
# Vamos ver como anda essa atualidade!
